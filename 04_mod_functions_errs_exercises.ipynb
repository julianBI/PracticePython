# %% [markdown]
# ##04 Mod Functions
# ###Exercises

# %% [markdown]
# How to determine whether a year is a leap year
# To determine whether a year is a leap year, follow these steps:
#
# If the year is evenly divisible by 4, go to step 2. Otherwise, go to step 5.
#
# If the year is evenly divisible by 100, go to step 3. Otherwise, go to step 5.
#
# If the year is evenly divisible by 400, go to step 4. Otherwise, go to step 5.
#
# The year is a leap year (it has 366 days).
#
# The year is not a leap year (it has 365 days).

# %%
# this is the first approach

year = int(input("Enter a year: "))  
divi=year % 4
divi100=year % 100
divi400= year % 400
if divi==0 and divi100!=0 or divi400 == 0:
  print("The year is Leap")
else:
  print("This year is no Leap")
# Out:
# Enter a year: 2089
# This year is no Leap

# %%
# this is a second approach

year = int(input("Enter a year: "))  
if (year % 4) == 0:  
   if (year % 100) == 0:  
       if (year % 400) == 0:  
           print("{0} is a leap year".format(year))  
       else:  
           print("{0} is not a leap year".format(year))  
   else:  
       print("{0} is a leap year".format(year))  
else:  
   print("{0} is not a leap year".format(year))
# Out:
# Enter a year: 2089
# 2089 is not a leap year

# %% [markdown]
# Optional Exercise (Extra Points) Iterate over a list of over 10 numbers.  This list is made from user input, and might not have 10 numbers in it. After you reach the end of the list, make the rest of the numbers to be interpreted as a 0.

# %%
# get the numbers using list comprehension 
x = [int(x) for x in input("Enter multiple value follow by (,): ").split(",")] 
lenA=((len(x))-1)
for i in range(0,10):
  if i<=lenA:
    print(x[i])
  else:
    print(0)

# %% [markdown]
# Optional Exercise (Extra Points). Given a list iterate it and display numbers which are divisible by 5 and if you find number greater than 150 stop the loop iteration.

# %%
import random
n=int(input('number of iteration ='))
for i in range(n):
  num=random.randint(0, 800)
  nummod=num % 5
  numdiv=num / 5
  if numdiv > 150:
    print("the division is greater that 150")
    break
  elif nummod == 0:
    print("this number aredivisible by 5---> {} / {} = {}".format(num,5,numdiv))
# Out:
# number of iteration =20
# this number aredivisible by 5---> 465 / 5 = 93.0
# the division is greater that 150
