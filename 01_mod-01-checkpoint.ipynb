# %% [markdown]
# #Exercises 01_mod-01-checkpoint
# ####**Julian Londono**

# %% [markdown]
# Exiercises using variables

# %%
# Store your own version of the message "Hello World" in a variable, and print it
message="Julian is ready"
print(message)
# Out:
# Julian is ready

# %%
#Store a new message in the same variable, and then print that new message.
message="Hellow World!"
print(message)
# Out:
# Hellow World!

# %%
#Find a quote and  Print the quote.
#In this exercise I'm using a concatenation and whitespace characters

e="'Life is like riding a bicycle. To keep your balance, you must keep moving'"
print('This quote belong to Albert Einsten and said: \n' + e.lstrip())
# Out:
# This quote belong to Albert Einsten and said:
# 'Life is like riding a bicycle. To keep your balance, you must keep moving'

# %%
#Store your first name, in lowercase, in a variable.
#Using that one variable, print your name in lowercase, Titlecase, and UPPERCASE.
name='julian'
lastname="londono"
print(name.lower())

name='julian'
print(name.title())

name='julian'
print(name.upper())

#Store your first name and last name in separate variables, and then combine them to print out your full name
print(name.title()+" "+ lastname.title())
# Out:
# julian
# Julian
# JULIAN
# Julian Londono

# %%
'''Store your first name in a variable, but include at least two kinds of whitespace on each side of your name.
Print your name as it is stored.
Print your name with whitespace stripped from the left side, then from the right side, then from both sides.'''

name =' julian '
print(name.lstrip())
print(name.rstrip())
print(name.strip())
# Out:
# julian
#  julian
# julian

# %%
name = ' eric '

print(name.lstrip())
print(name.rstrip())
print(name.strip())
# Out:
# eric
#  eric
# eric

# %% [markdown]
# Exercises using Numbers

# %%
'''Write a program that prints out the results of at least one calculation for 
each of the basic operations: addition, subtraction, multiplication, division, and exponents.'''
print('Programa  de Operaciones Matematicas \n')
a=10
b=20
c=30
suma=a+b+c
resta=a-b-c
print('Addition')
print(suma)
print('subtrascction')
print(resta)
# Out:
# Programa  de Operaciones Matematicas
#
# Addition
# 60
# subtrascction
# -40

# %%
#Print the result of this calculation using the standard order of operations.

print("The result of this operation is as follow: Multiplication before Addition \n")
print('3 + 6 * 2')
variable= 3 + 6 * 2
print(variable)
# Out:
# The result of this operation is as follow: Multiplication before Addition
#
# 3 + 6 * 2
# 15

# %%
#Print the result of this calculation using the standard order of operations.

print("The result of this operation is as follow: Suma despues multiplicacion \n")
print('(3 + 6) × 2')
variable= (3 + 6) * 2
print(variable)
# Out:
# The result of this operation is as follow: Suma despues multiplicacion
#
# (3 + 6) × 2
# 18

# %%
#The Zen of Python by Tim Peters are 20 guidelines for the design of the Python language. 
#Your Python code doesn’t necessarily have to follow these guidelines, but they’re good to keep in mind.
#The Zen of Python is an Easter egg, or hidden joke, that appears if you run import this
import this
